# %%
# !pip install pandas
# !pip install fsspec
# !pip install --upgrade huggingface_hub
# !pip install sqlalchemy
# !pip install datasets
# Out:
# Requirement already satisfied: pandas in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: fsspec in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (2025.7.0)
# Requirement already satisfied: huggingface_hub in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (0.34.3)
# Requirement already satisfied: filelock in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from huggingface_hub) (2025.7.0)
# Requirement already satisfied: packaging>=20.9 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from huggingface_hub) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from requests->huggingface_hub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from requests->huggingface_hub) (2025.7.14)
# Requirement already satisfied: sqlalchemy in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (2.0.41)
# Requirement already satisfied: greenlet>=1 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from sqlalchemy) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from sqlalchemy) (4.12.2)
# Collecting datasets
#   Downloading datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from datasets) (2.3.1)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-21.0.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from datasets) (2.3.1)
# Requirement already satisfied: requests>=2.32.2 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from datasets) (0.34.3)
# Requirement already satisfied: packaging in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from datasets) (6.0.2)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.12.15-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.7.0-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading multidict-6.6.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading propcache-0.3.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading yarl-1.20.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
# Requirement already satisfied: idna>=2.0 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from huggingface-hub>=0.24.0->datasets) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2025.7.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/michaelpollind/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading aiohttp-3.12.15-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 32.7 MB/s eta 0:00:00
# Downloading multidict-6.6.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (254 kB)
# Downloading yarl-1.20.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.7.0-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (232 kB)
# Downloading propcache-0.3.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (206 kB)
# Downloading pyarrow-21.0.0-cp313-cp313-manylinux_2_28_x86_64.whl (42.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 64.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading xxhash-3.5.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Installing collected packages: xxhash, pyarrow, propcache, multidict, fsspec, frozenlist, dill, aiohappyeyeballs, yarl, multiprocess, aiosignal, aiohttp, datasets
#   Attempting uninstall: fsspec38;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/13 [pyarrow]
#     Found existing installation: fsspec 2025.7.037m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/13 [pyarrow]
#     Uninstalling fsspec-2025.7.0:7m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/13 [pyarrow]
#       Successfully uninstalled fsspec-2025.7.0;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/13 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [datasets]237m━━━ 12/13 [datasets]]
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 datasets-4.0.0 dill-0.3.8 frozenlist-1.7.0 fsspec-2025.3.0 multidict-6.6.3 multiprocess-0.70.16 propcache-0.3.2 pyarrow-21.0.0 xxhash-3.5.0 yarl-1.20.1

# %%
# Out:
#   Cell In[7], line 1
#     hf auth login
#        ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from datasets import load_dataset,

# %%
ds = load_dataset("jeggers/more_crosswords")
df = ds["train"].to_pandas()

# %%
# Out:
#         pubid  year  answer                                           clue  \
# 0         atc  1997     ABA                              Litigator's group
# 1         atc  1997   ACTOR                                       Thespian
# 2         atc  1997    ADES                                 Summer coolers
# 3         atc  1997     ADS                              Newspaper revenue
# 4         atc  1997    AFRO                                   Head of hair
# ...       ...   ...     ...                                            ...
# 6044632   wsj  2015   ZONES                         Shipping map divisions
# 6044633   wsj  2015     ZOO                                       Madhouse
# 6044634   wsj  2015    ZORA                       Author ___ Neale Hurston
# 6044635   wsj  2015  ZSAZSA   Hollywood celeb whose surname is unnecessary
# 6044636   wsj  2015   ZTILE  It's worth 30 points on a Triple Letter Score
#
#          length                 hint                hint2                hint3
# 0             3  The 3rd letter is A  The 1st letter is A  The 2nd letter is B
# 1             5  The 1st letter is A  The 4th letter is O  The 3rd letter is T
# 2             4  The 1st letter is A  The 4th letter is S  The 2nd letter is D
# 3             3  The 2nd letter is D  The 3rd letter is S  The 1st letter is A
# 4             4  The 1st letter is A  The 2nd letter is F  The 4th letter is O
# ...         ...                  ...                  ...                  ...
# 6044632       5  The 3rd letter is N  The 1st letter is Z  The 4th letter is E
# 6044633       3  The 2nd letter is O  The 3rd letter is O  The 1st letter is Z
# 6044634       4  The 2nd letter is O  The 4th letter is A  The 1st letter is Z
# 6044635       6  The 5th letter is S  The 1st letter is Z  The 3rd letter is A
# 6044636       5  The 3rd letter is I  The 2nd letter is T  The 5th letter is E
#
# [6044637 rows x 8 columns]

# %%
from sqlalchemy import create_engine
disk_engine = create_engine('sqlite:///crossword.db')
df.to_sql('crossword', disk_engine, if_exists='append')
# Out:
# 6044637
